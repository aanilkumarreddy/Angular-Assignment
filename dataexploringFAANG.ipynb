# %% [markdown]
# <a href="https://colab.research.google.com/github/aanilkumarreddy/Angular-Assignment/blob/main/dataexploringFAANG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import numpy as np
import pandas_datareader as pdr
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
import seaborn as sns
import time

plt.style.use('fivethirtyeight')

# %%
appleCSV = pd.read_csv('AAPL.csv',parse_dates=['Date'],)
appleCSV
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-01-02   38.722500   39.712502   38.557499   39.480000   38.277519
# 1   2019-01-03   35.994999   36.430000   35.500000   35.547501   34.464794
# 2   2019-01-04   36.132500   37.137501   35.950001   37.064999   35.936077
# 3   2019-01-07   37.174999   37.207500   36.474998   36.982498   35.856098
# 4   2019-01-08   37.389999   37.955002   37.130001   37.687500   36.539619
# ..         ...         ...         ...         ...         ...         ...
# 799 2022-03-04  164.490005  165.550003  162.100006  163.169998  163.169998
# 800 2022-03-07  163.360001  165.020004  159.039993  159.300003  159.300003
# 801 2022-03-08  158.820007  162.880005  155.800003  157.440002  157.440002
# 802 2022-03-09  161.479996  163.410004  159.410004  162.949997  162.949997
# 803 2022-03-10  160.199997  160.389999  155.979996  158.520004  158.520004
#
#         Volume
# 0    148158800
# 1    365248800
# 2    234428400
# ...

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from datetime import datetime

plt.figure(figsize=(16,8))
plt.title('Apple stock price')
plt.plot(appleCSV['Open'])


plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import plotly.graph_objects as go
displayFig = pd.read_csv('AAPL.csv')

fig = go.Figure(data=[go.Candlestick(x=displayFig['Date'],
                open=displayFig['Open'], high=displayFig['High'],
                low=displayFig['Low'], close=displayFig['Close'])
                     ])

fig.update_layout(xaxis_rangeslider_visible=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(16,8))
plt.title('Apple Scatter plot')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=10)
plt.scatter(appleCSV['Date'], appleCSV['Close'])
plt.show()

# %%
googleCSV = pd.read_csv('GOOG.csv',parse_dates=['Date']);

plt.figure(figsize=(16,8))
plt.title('Google Scatter plot')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=10)
plt.scatter(googleCSV['Date'], googleCSV['Close'])
plt.show()

# %%
nflxcsv = pd.read_csv('NFLX.csv',parse_dates=['Date']);

plt.figure(figsize=(16,8))
plt.title('Netflix stock price')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=10)
plt.plot(nflxcsv['Date'], nflxcsv['Close'])
plt.show()

# %%
amzncsv = pd.read_csv('AMZN.csv',parse_dates=['Date']);
plt.figure(figsize=(16,8))
plt.title('Amazon stock price')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=10)
plt.plot(amzncsv['Date'], amzncsv['Close'])
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.title('Amazon Scatter plot')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=10)
plt.scatter(amzncsv['Date'], amzncsv['Close'])
plt.show()

# %%
fbCSV = pd.read_csv('FB.csv',parse_dates=['Date']);
plt.figure(figsize=(16,8))
plt.title('Facebook stock price')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=10)
plt.plot(fbCSV['Date'], fbCSV['Close'])
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.title('Facebook Scatter plot')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=10)
plt.scatter(fbCSV['Date'], fbCSV['Close'])
plt.show()
